# %%
#import
from animal_shelter import AnimalShelter

USER = "aacuser"
PASS = "pass"
HOST = "nv-desktop-services.apporto.com"
PORT = 30611

shelter = AnimalShelter(USER, PASS, HOST, PORT)
# Out:
# Connected to AAC.animals

# %%
# cell 2 – test create
sample_doc = {
    "animal_id": "A100999",
    "animal_type": "Dog",
    "breed": "Labrador Retriever",
    "name": "Coder",
    "color": "Black",
    "outcome_type": "Adoption"
}
print("Insert successful:", shelter.create(sample_doc))
# Out:
# Insert successful: True

# %%
# cell 3 – test read
docs = shelter.read({"breed": "Labrador Retriever"})
print("Documents found:", len(docs))
for d in docs[:2]:
    print(d)
# Out:
# Documents found: 19
# {'_id': ObjectId('688c2c02335cecd20877581c'), 'rec_num': 549, 'age_upon_outcome': '6 years', 'animal_id': 'A749092', 'animal_type': 'Dog', 'breed': 'Labrador Retriever', 'color': 'Brown', 'date_of_birth': '2011-01-12', 'datetime': '2017-05-13 17:22:00', 'monthyear': '2017-05-13T17:22:00', 'name': 'Lucas', 'outcome_subtype': '', 'outcome_type': 'Return to Owner', 'sex_upon_outcome': 'Neutered Male', 'location_lat': 30.288559394642, 'location_long': -97.3112421545338, 'age_upon_outcome_in_weeks': 330.531944444444}
# ...

# %%
# cell 4 – test update
# Change all "Coder" dogs to outcome_type="Transfer"
num_updated = shelter.update(
    {"name": "Coder"},
    {"outcome_type": "Transfer"}
)
print("Documents updated:", num_updated)

# Verify with a read:
print("After update:", shelter.read({"name": "Coder"}))
# Out:
# Documents updated: 1
# After update: [{'_id': ObjectId('688c2f5bd9d97f412072cea1'), 'animal_id': 'A100999', 'animal_type': 'Dog', 'breed': 'Labrador Retriever', 'name': 'Coder', 'color': 'Black', 'outcome_type': 'Transfer'}]

# %%
# cell 5 – test delete
# Remove the “Coder” document
num_deleted = shelter.delete({"name": "Coder"})
print("Documents deleted:", num_deleted)

# Verify removal
print("Remaining Coder docs:", shelter.read({"name": "Coder"}))
# Out:
# Documents deleted: 1
# Remaining Coder docs: []
